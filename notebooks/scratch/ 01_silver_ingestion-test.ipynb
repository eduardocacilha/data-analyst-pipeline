# %%
spark.sql("SELECT COUNT(*) AS total_linhas, MIN(_ingested_at) AS primeiro_ingest, COUNT(DISTINCT _source_file) AS arquivos_distintos FROM workspace.silver.stg_taxi_trips").show()

# %%
spark.sql("select * from workspace.silver.stg_taxi_trips").show()

# %%
spark.sql("select * from workspace.silver.stg_taxi_trips").describe()

# %%
df = spark.table("workspace.silver.stg_taxi_trips")

# %%
df.printSchema()      # mostra as colunas e tipos, tipo um df.info() do pandas
df.count()             # total de linhas
display(df.limit(20))  # visualização bonita, com paginação (melhor que .show())

# %%
df.describe().show()

# %%
total = df.count()
df.describe().filter("summary = 'count'").show(truncate=False)

# %%
from pyspark.sql import functions as F

df = spark.table("workspace.silver.stg_taxi_trips")

nulos = df.select([
    F.sum(F.col(c).isNull().cast("int")).alias(c) for c in df.columns
])

display(nulos)

# %%
spark.sql("select * from workspace.silver.stg_taxi_trips").show()

# %%
spark.table("workspace.silver.stg_taxi_trips").printSchema()

# %%
# %sql
SELECT COUNT(*)
FROM workspace.bronze.nyc_taxi_trips
WHERE passenger_count != CAST(passenger_count AS INT)
   OR ratecodeid != CAST(ratecodeid AS INT);
